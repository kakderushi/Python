# %%
1) values and expreession are follows:
values are:-87.8, 'hello' ,6
Expression: *, /,+,-


2)what are diffrence between string and variable

String:
    Strings are data type, so we can use them to store characters type of data.
    for example: name="Rushikesh"
    
 Variable:
         Variable are the symbols that you can use to store data in a program. 
         we can think of them as an empty box that you fill with some data of value.
         In variable we could store any type of data like integer,float,string.
         
 3)Describe three different data types
   
           1)  int: This data types is used store integer values in the variable.
                 example:a=10
                 above example show a is varible which stored integer value in a.
                 
           2)float:This data type is used to stored decimal point of value in the a.
                example: a=23.00
                above example show a is variable which stored decimal value in the a.
                
                
           3)str: This is store characters values in the variable.
                    example:name="Rushi"
                    above example name variable store characters value.
                    
                    
   4)What is an expresssion made of? what do 
        An expression is a conduct made up of variable ,operator and method invocations,
        which are constructed according to the syntax of the language ,that evaluates to a single value.

5) this assingment statements,like spam=10, what is the diffrence between an expressions and a statement.
        expressions:
        Expressions in python produce some value or result after being interpreted by the python interpreter.
        for example: 1,has a certain value while go()may be executed or not.
        
        statement:
        Statement in python is used to creating variables or displaying values.
        example: line or a block of code is a statement.
            
6)After running the following code,what does the variable bacon contain?

        bacon=22
        bacon+1
        
        ans: variable bacon contain 22
7)what should the values of the following two terms be?
        
    'spam'+'spamspam'
    'spam'*3
    
    frist term=spamspamspam
    second term=spamspamspam
    
8)why is eggs valid variable name while 100 is invalid?
    eggs is valid variable name because eggs follow varaible
    declarations rule,which are it start wiht character rather than
    any numeric value or special characters.
    
    100 is invalid variable name beacuse of it does'nt follow variable
    declaration rule ,such as start with numeric value.
    
9)what three functions can be used to get the intger,floating-point number or string version of a value?

        these three functions are followed:
            int(),float()and str()
        
        
10)why does this expressions cause an error? how can you fix it?
'i have eaten'+99+'burritos.'

This statement cause errror  beacause we could concatenate only  string value 
In above example we used numeric value. that is reason it through an error.

writing rather than above statement we can write it like that,

'l have eaten'+'99'+'burritos.'
