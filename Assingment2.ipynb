# %%
1) what are the two values of the boolean data type? how do write them?

    ans: True and False are the two values of boolean data type.
        The Standard way of writing these two values:
        a=True
        b=False
        
        
        
2)what are the three diffrent types of boolean operators?
    
    ans:Diffrent  three types of operators
        1)and
        2)or
        3)not
        

3)make a list of each Boolean operator truth tables(eg.every possible combination of boolean types for the operator and what it evaluate)
	1)and operator
	| Input A | Input B | Output |
	|---------|---------|--------|
	|   True  |   True  |  True  |
	|   True  |  False  | False  |
	|  False  |   True  | False  |
	|  False  |  False  | False  |

2)or opetator
	| Input A | Input B | Output |
	|---------|---------|--------|
	|   True  |   True  |  True  |
	|   True  |  False  |  True  |
	|  False  |   True  |  True  |
	|  False  |  False  | False  |

3)not operator
  	| Input | Output |
	|-------|--------|
	|  True | False  |
	| False |  True  |





4)what are the values of the following expressions
        (5>4)and (3==5)
        not(5>4)
        (5>4)or(3==5)
        not(5>4)or(3==5)
        (True and True)and(True==False)
        (not False)or(not True)
        
        output:
                 False
                 False
                 True
                 False
                 False
                 True
                    

5)what are the six comparison operator?
        
    ans:Six comparison operator are:
            1)Python less than(<) operator
            2)Pthon grater than(>) Operator
            3)Python less than or equal to(<=)
            4)python grater than or equal to(>=)
            5)python eqaul to(==) operator
            6)Python not equla to(!=) operator
            
            
6)How do you tell the difference between the equal to and assignment operator?
Describe a conditon and when you would use one.
    
    ans:Equal to is comparison operator which is used for
            comparing two values 
            
            while assignment operator is used to assign the value
            to the variable.
                 
                
7)identtify the blocks of code

		spam=0
		if spam==10:
		print('eggs')
		if spam>5:
		print('bacon')
		else:
		print('ham')
		print('spam')
		print('spam')


		output:ham


8)write a code that print Hello if 1 is stored in spam,
prints Howdy if 2 is stored,and prints Greetings! if anything else is stored in spam

		code:
			
		spam=1
		if spam==1:
		print('Hellow')
		if spam==2:
		print('Howdy')
		else:
		print('Greeting!')


9)if you progrmmae is stuck is an endless loop,what keys you'll press?
	
	ans:CTRL+C

10)How can you tell the diffrence between break and continue

	ans:break keyworld is used to terminate or stop the loop 		
		while it dong a contineous task as specific point.

		Continue:continue is keyworld is used to skip current iteration 
		of a loop.

11)In for loop, what is the diffenece between range(10),range(0,10) and range(0,10,1)?
		

		ans:
			range(10):range(stop) In for loop range(10) is last index of the iteration.
			we could print the values of loop upto range(10) it totally 
			depends on user where to start the index.

			range(0,10):range(start,stop) In for loop range(0,10) is in 0 is start index
			and 10 is last index.here we start with 0 and end with 10
			means that we print values between 0 to 10.

			range(0,10,1):(start,stop,step) In for loop range(0,10,1) is 0 is start index
			,10 is last index and 1 is step.here we start with 0 and end with 10 but that 
			time we forward our loop iteration with 1.


12)Write a short program that prints the numbers 1 to 10 using for loop
then wrie an equivalent program that prints the numbers 1 to 10 using while loop
	
		ans:
		1)using for loop
		Code:for i in range(0,10):
				print(i)

		2)while loop
		i=0;
		Code:while i>=10:
			print(i)
			i++

13)if you had a function named bacon() inside a module named spam,
how would you call it after importing spam.

		ans:
		import spam
		def bacon():
		print("hello world")

		bacon()
